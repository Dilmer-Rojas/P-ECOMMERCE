# %% [markdown]
# # Analisis EDA y Estadistica Descriptiva

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
files = ["categorias", "clientes", "metodos_pago", "productos", "ventas"]
for file in files:
    df = pd.read_csv(f"../../data/raw/{file}.csv")

# %%
while True:
    try:
        df = pd.read_csv(f"../../data/raw/{file}.csv")
        head = df.head()
        break
    except FileNotFoundError:
        print(f"Archivo {file}.csv no encontrado. Intentando nuevamente...")

# %%
print("Tamaño del dataset: {df_shape[0]} filas y {df_shape[1]} columnas".format(df_shape=df.shape))
# Out:
# Tamaño del dataset: 3029 filas y 7 columnas
