# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ruta = '../data/raw/ECOMMERCE.xlsx'
dfs = pd.read_excel(ruta, sheet_name=None)

# %%
clientes = dfs['clientes']
categorias = dfs['categorias']
metodos_pago = dfs['metodos_pago']
ventas = dfs['ventas']
productos = dfs['productos']
