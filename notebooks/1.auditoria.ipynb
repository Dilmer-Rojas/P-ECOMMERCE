# %% [markdown]
# # Auditoría de Datos (Data Quality Check)
#
# Antes del análisis se realizaron verificaciones de calidad de datos:
#
# • Detección de valores nulos
#
# • Identificación de registros duplicados
#
# • Revisión de inconsistencias
#
# • Verificación de tipos de datos
#
# Objetivo: asegurar que el análisis se realice sobre datos confiables.

# %%
# Importación de módulos necesarios
import pandas
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Carga de datos

# %%
# Detección de nulos
