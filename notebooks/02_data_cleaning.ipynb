# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar data
file = pd.read_excel("../data/raw/ECOMMERCE.xlsx", sheet_name=None)

# %%
data = {
    "Clientes": file["clientes"],
    "Productos": file["productos"],
    "Ventas": file["ventas"],
}

# %%
Clientes = data["Clientes"]
Productos = data["Productos"]
Ventas = data["Ventas"]

# %%
Clientes.describe()
# Out:
#        ID_Cliente                 Fecha_Registro
# count  326.000000                            326
# mean   163.500000  2023-08-14 00:30:55.214723840
# min      1.000000            2023-03-19 00:00:00
# 25%     82.250000            2023-05-29 12:00:00
# 50%    163.500000            2023-08-22 00:00:00
# 75%    244.750000            2023-10-28 18:00:00
# max    326.000000            2023-12-29 00:00:00
# std     94.252321                            NaN
